# %%
from music21 import *
s = converter.parse('/home/zoltan/recent impro/171intro.midi')

# %%
s.analyze('key')
# Out:
# <music21.key.Key of A major>

# %%
s.show()

# %%
from music21.figuredBass import checker
functionToApply = checker.parallelOctaves
checker.checkConsecutivePossibilities(s, functionToApply, debug=True)
# Out:
# Function To Apply: parallelOctaves
# (Offset A, End Time A):  (Offset B, End Time B):  Part Numbers:
# (19.5, 20.0)             (20.0, 21.0)             (1, 2)
# (23.5, 24.0)             (24.0, 24.5)             (1, 2)

# %%
functionToApply = checker.parallelFifths
checker.checkConsecutivePossibilities(s, functionToApply, debug=True)
# Out:
# Function To Apply: parallelFifths
# (Offset A, End Time A):  (Offset B, End Time B):  Part Numbers:
# (57.5, 58.0)             (58.0, 58.5)             (1, 2)

# %%
s.show()
